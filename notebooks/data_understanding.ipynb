# %%
import pandas as pd

data = pd.read_csv('../dataset/raw_data/Country Wise Yearly VIsitors.csv')

data.head()
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  63 non-null     object
#  1   2014     63 non-null     int64
#  2   2015     63 non-null     int64
#  3   2016     63 non-null     int64
#  4   2017     63 non-null     int64
#  5   2018     63 non-null     int64
#  6   2019     63 non-null     int64
#  7   2020     63 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 4.1+ KB
#                2014          2015          2016          2017          2018  \
# count  6.300000e+01  6.300000e+01  6.300000e+01  6.300000e+01  6.300000e+01
# mean   1.178705e+05  1.231695e+05  1.350226e+05  1.540946e+05  1.620504e+05
# std    2.083472e+05  2.298462e+05  2.594044e+05  3.355741e+05  3.521297e+05
# min    6.867000e+03  7.036000e+03  7.961000e+03  9.241000e+03  9.201000e+03
# 25%    2.574450e+04  2.358550e+04  2.215750e+04  2.486000e+04  2.738700e+04
# 50%    4.494800e+04  4.517100e+04  4.822700e+04  4.960700e+04  4.932200e+04
# 75%    1.112195e+05  1.151330e+05  1.153695e+05  1.412350e+05  1.522205e+05
# max    1.118983e+06  1.213624e+06  1.380409e+06  2.156557e+06  2.256675e+06
#
#                2019           2020
# count  6.300000e+01      63.000000
# mean   1.678953e+05   42087.873016
# std    3.861400e+05   90274.260970
# min    9.788000e+03    2854.000000
# 25%    2.882300e+04    7996.500000
# 50%    4.863900e+04   12561.000000
# 75%    1.390085e+05   34519.000000
# max    2.577727e+06  549273.000000

# %%
import pandas as pd

# load data
data = pd.read_csv('../dataset/raw_data/Country Wise Yearly VIsitors.csv')

# convert to long format
data_long = data.melt(id_vars=['Country'], 
                      var_name='Year', 
                      value_name='Visitors')

# fix datatype
data_long['Year'] = data_long['Year'].astype(int)

# %%
top_countries = data_long.groupby('Country')['Visitors'].sum().sort_values(ascending=False)

# %%
data_2014 = data_long[data_long['Year'] == 2014]
data_2019 = data_long[data_long['Year'] == 2019]

growth = data_2019.set_index('Country')['Visitors'] - data_2014.set_index('Country')['Visitors']

# %%
import os
os.makedirs('../outputs/results', exist_ok=True)

with open('../outputs/results/summary.txt', 'w') as f:
    f.write("Top Country: " + str(top_countries.idxmax()) + "\n")
    f.write("Highest Growth Country: " + str(growth.idxmax()) + "\n")
    f.write("Lowest Growth Country: " + str(growth.idxmin()) + "\n")
